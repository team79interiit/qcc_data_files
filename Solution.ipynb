# %%
# !pip install cplex
# !pip install datetime
# !pip install qiskit
# !pip install qiskit_algorithms
# !pip install qiskit_optimization

# %%
# __________________________________ ALL REQUIRED IMPORTS __________________________________

import sqlite3
import pandas as pd
from datetime import datetime

# %%
# __________________________________ LOADING DATA INTO A DATABASE __________________________________

# URLs for data sources
DATA_URLS = {

    "inventory": "https://raw.githubusercontent.com/team79interiit/qcc_data_files/main/inv.csv",
    "schedule": "https://raw.githubusercontent.com/team79interiit/qcc_data_files/main/sch.csv",
    "pnr_booking": "https://raw.githubusercontent.com/team79interiit/qcc_data_files/main/pnrb.csv",
    "pnr_passenger": "https://raw.githubusercontent.com/team79interiit/qcc_data_files/main/pnrp.csv",
    "pnr_booking_template": "https://raw.githubusercontent.com/team79interiit/qcc_data_files/main/booking_template.csv",

}

DATABASE = "data.db"

# %%
# Function to load data from URLs into dataframes
def load_data(data_urls=dict()):

    data_frames = {}

    for key, url in data_urls.items():

        data_frames[key] = pd.read_csv(url)

    return data_frames

# %%
# Function to add a DataFrame as a table to a SQLite database
def add_table_to_database(dataframe, tablename=''):

    try:

        # Establish connection to SQLite database
        connection = sqlite3.connect(DATABASE)

        # Add DataFrame as a table to the database
        dataframe.to_sql(tablename, connection, if_exists='fail', index=False)
        print(f"Table '{tablename}' added to the database.")

    except Exception as e:

        # Handle case where table already exists in the database
        print(f"{e}")

    finally:

        # Ensure the connection is closed after operations
        connection.commit()
        connection.close()

# %%
# Load data frames from URLs
data_frames = load_data(DATA_URLS)

# Select specific tables to add to the database
tables_to_add = {

    'inv': data_frames['inventory'],
    'pnrb': data_frames['pnr_booking'],
    'pnrp': data_frames['pnr_passenger'],
}

# Add selected tables to the database
for table_name, df in tables_to_add.items():
  add_table_to_database(df, table_name)
# Out:
# Table 'inv' already exists.
# Table 'pnrb' already exists.
# Table 'pnrp' already exists.

# %%
#  ___________________ WE ARE ASSUMING THAT THE FOLLOWING MINIMAL INFO IS GIVEN ON CHANGES IN SCHEDULE ______________

# Define constants for types of changes
CANCELLED = "Cancelled"
DELAYED = "Delayed"

# List of available types of changes
type_of_changes = [CANCELLED, DELAYED]

# Information about changes in flight schedules
changes = [
    {
        "Flight Number": 2504,
        "Departure Date": '4/3/2024',
        "Type of change": CANCELLED,
    },
    {
        "Flight Number": 3723,
        "Departure Date": "04/07/2024",
        "Type of change": DELAYED,
        "New Departure Date Time": "2024-05-05 11:52:00",
        "New Arrival Date Time": "2024-05-05 20:30:00",
    }
]

# Since the date & time in database are inconsistent we are using a global data structre to keep track of format while writing code
FORMATS = {
    "inv":[{
        "DepartureDate" : "%m/%d/%Y",
        "DepartureDateTime": "%Y-%m-%d %H:%M:%S",
        "ArrivalDateTime": "%Y-%m-%d %H:%M:%S",
    }, True], # True indicates that there is 0 infront of single digit numbers in dates

    "pnrb":[{
        "DEP_DT" : "%m/%d/%Y",
        "DEP_DTML" : "%m/%d/%Y %H:%M",
        "ARR_DTML": "%m/%d/%Y %H:%M",
        "DEP_DTMZ": "%m/%d/%Y %H:%M",
        "ARR_DTMZ": "%m/%d/%Y %H:%M",
    }, False], # False indicates that there is no 0 infront of single digit numbers in dates
}

# %%
def search_for_affected_flight_inv(flight_number, departure_date):

  connection = sqlite3.connect(DATABASE)
  cursor = connection.cursor()

  sql_search_query = '''
  SELECT * FROM inv
  WHERE FlightNumber = ? and DepartureDate = ?;
  '''

  # The following code will make sure the departure_date is in correct format & also adds 0's if single digit date
  try:
    departure_date = datetime.strptime(departure_date, "%m/%d/%Y").strftime("%m/%d/%Y")
  except Exception as e:
    print("departure date is not in %m/%d/%Y format")

  cursor.execute(sql_search_query,(flight_number, departure_date))
  results = cursor.fetchall()

  connection.commit()
  connection.close()
  return results

# %%
def search_for_affected_pnrb(flight_number, departure_date):

    connection = sqlite3.connect(DATABASE)
    cursor = connection.cursor()

    sql_search_query = '''
    SELECT * FROM pnrb
    WHERE FLT_NUM = ? AND DEP_DT = ?;
    '''

    # Attempt to convert departure_date to the correct format
    try:
        departure_date = datetime.strptime(departure_date, "%m/%d/%Y").strftime("%m/%d/%Y")
    except Exception as e:
        print("Departure date is not in the format %m/%d/%Y.")

    # Remove leading zeros from single-digit days or months
    departure_date_parts = departure_date.split('/')
    departure_date = '/'.join(str(int(part)) for part in departure_date_parts)

    cursor.execute(sql_search_query, (flight_number, departure_date))
    results = cursor.fetchall()

    connection.commit()
    connection.close()
    return results

# %%
def update_inv_with_newdatetime (new_dept_time='', new_arr_time='', inv_id=''):

    connection = sqlite3.connect(DATABASE)
    cursor = connection.cursor()

    # Using parameterized query to avoid SQL injection
    sql_update_query = '''
    UPDATE inv
    SET "DepartureDateTime" = ?, "ArrivalDateTime" = ?
    WHERE InventoryId = ? '''

    # Attempt to convert departure_date to the correct format
    try:

        new_dept_time = datetime.strptime(new_dept_time, "%Y-%m-%d %H:%M:%S").strftime("%Y-%m-%d %H:%M:%S")

    except Exception as e:

        print("new_dept_time is not in the format %Y-%m-%d %H:%M:%S")

    # Attempt to convert departure_date to the correct format
    try:

        new_arr_time = datetime.strptime(new_arr_time, "%Y-%m-%d %H:%M:%S").strftime("%Y-%m-%d %H:%M:%S")

    except Exception as e:

        print("new_arr_time is not in the format %Y-%m-%d %H:%M:%S")

    # Tuple of values to be substituted into the query
    values = (new_dept_time, new_arr_time, inv_id)

    cursor.execute(sql_update_query, values)
    connection.commit()
    connection.close()

# %%
def add_affected_passengers_to_database(inventory_id, flight_number, departure_date):

  pnr_booking_template_df = pd.read_csv(DATA_URLS["pnr_booking_template"])
  connection = sqlite3.connect(DATABASE)
  cursor = connection.cursor()

  # Identify the affected passengers and pass it on to post process
  # Step 1 : Create a table with Inventory Id of the affected flight as table name
  try:

    table_name = inventory_id.replace('-','_')
    pnr_booking_template_df.to_sql(table_name, connection, if_exists='replace', index=False)

    # Step 2 : Add the affected passengers to the table
    affected_pnrs = search_for_affected_pnrb(flight_number, departure_date)

    for pnr in affected_pnrs:

      insert_data_query = f'''
      INSERT INTO  {table_name}
      VALUES {pnr}
      '''
      cursor.execute(insert_data_query)

  except Exception as e:

    print(f"HURRAY! -- The passengers of the flight on this Inventory entry are already identified | {e} ")

  connection.commit()
  connection.close()
  return

# %%
affected_flights = dict()

for change in changes:

  flight_number = change["Flight Number"]
  departure_date = change["Departure Date"]
  type_of_change = change["Type of change"]

  search_result = search_for_affected_flight_inv(flight_number, departure_date)

  if search_result == []:

    print(f" OOPS! ----- No Inventory entry exists for the given change : {change} ------ ")
    continue

  search_result = search_result[0]

  # Preparing to handling the change in schedule
  # dictionary to pass the information to the quantum solver

  inventory_id = search_result[0]

  if type_of_change in type_of_changes:

    add_affected_passengers_to_database(inventory_id, flight_number, departure_date)

    if type_of_change == CANCELLED:

      affected_flights[inventory_id] = type_of_change

    elif type_of_change == DELAYED:

      affected_flights[inventory_id] = type_of_change

      new_departure_date_time = change["New Departure Date Time"]
      new_arrival_date_time = change["New Arrival Date Time"]

      update_inv_with_newdatetime(new_departure_date_time, new_arrival_date_time, inventory_id)

    else:

      print(f"----- Unidentified type of change : {type_of_change} ------")

# print(affected_flights)

# %%
# __________________________________ RULE ENGINE __________________________________

MAX_ETD_FROM_IMPACTED_FLIGHT_IN_HOURS = 72
MAX_CONNECTION_TIME = 12
MIN_CONNECTION_TIME = 1

# This reference table can be used for identifying the cabin for each class of service
CABIN_CLASS_MAP = {
    "J": ["A", "D", "J"],
    "F": ["F", "B"],
    "Y": ["S", "V", "W", "Z", "O", "S", "T", "U", "M", "N", "Y"]
}

# This will be Used when Original class is not available to rebook
CLASS_TO_CLASS_MAP = {
    "A": ["F", "S"],
    "S": ["F", "A"],
    "F": ["S", "A"],
    "J": ["O", "C", "I"],
    "C": ["O", "J", "I"],
    "I": ["J", "C", "O"],
    "O": ["J", "C", "I"],
    "Y": ["B", "P", "Z"],
    "B": ["Y", "P", "Z"],
}

# 1. This is only applicable if Downgrade is on.
# 2. If Downgrade to Cabin J/F then refer to Downgrade class respectively
DOWNGRADE_CLASS_MAP = {
    "J": "Y",
    "F": "Y",
}

# 1. This is only applicable if Upgrade is enabled.
# 2. If Upgraded to Cabin F/J then refer to Upgrade class respectively
UPGRADE_CLASS_MAP = {
    "Y": "F",
    "F": "J",
}

class PNR:
    def __init__(self):

        self.Recloc = None
        self.TYPE = None
        self.SSR = None
        self.Cabin = None
        self.Class = None
        self.Number_Of_Down_lineConnections = 0
        self.PaidServices = None
        self.Booked_As = None
        self.Number_of_PAX = None
        self.Loyalty = None
        self.ForceKickOut = None

    def Score(self):

        Special_Services = ["INFT", "WHCR", "WCHS", "WCHC", "LANG", "CHILD", "EXST", "BLND", "DEAF"]
        total_score = None
        self.ForceKickOut = True

        # SSR Score
        if self.TYPE == "PNR.INDIVIDUAL" and self.SSR in Special_Services:
            total_score += 200

        # Cabin Score
        if self.TYPE == "PNR.INDIVIDUAL" and self.Cabin:
            cabin_score_mapping = {
                "J": 2000,
                "F": 1700,
                "Y": 1500
            }
            total_score += cabin_score_mapping.get(self.Cabin, 0)

        # Class Score
        if self.TYPE == "PNR.INDIVIDUAL" and self.Class:
            class_score_mapping = {
                "A": 1000,
                "C": 700,
                "K": 500,
            }
            total_score += class_score_mapping.get(self.Class, (0, 0))[0]

        # Connection Score
        if self.TYPE == "PNR.INDIVIDUAL" and self.Number_Of_Down_lineConnections is not None:
            total_score += 100 * self.Number_Of_Down_lineConnections

        # Paid Service Score
        if self.TYPE == "PNR.INDIVIDUAL" and self.PaidServices == "Yes":
            self.ForceKickOut = False
            total_score += 200

        # Booking-Type Score
        if self.TYPE == "PNR.INDIVIDUAL" and self.Booked_As == "Group":
            self.ForceKickOut = False
            total_score += 500

        # No of PAX Score
        if self.TYPE == "PNR.INDIVIDUAL" and self.Number_of_PAX is not None:
            self.ForceKickOut = False
            total_score += 50 * self.Number_of_PAX

# %%
def get_affected_pnrb (table_name):

  connection = sqlite3.connect(DATABASE)
  cursor = connection.cursor()

  sql_search_query = f'''
  SELECT * FROM {table_name}
  '''

  cursor.execute(sql_search_query)
  results = cursor.fetchall()

  connection.commit()
  connection.close()
  return results

# %%
flights = list(affected_flights.keys())

# %%
import pandas as pd
import numpy as np
import datetime as dt
from qiskit_algorithms import QAOA
from qiskit_optimization.problems import QuadraticProgram
from qiskit_optimization.converters import QuadraticProgramToQubo
import copy
from qiskit_algorithms import NumPyMinimumEigensolver
from qiskit_optimization.algorithms import MinimumEigenOptimizer, WarmStartQAOAOptimizer, CplexOptimizer
from qiskit.primitives import Sampler
from qiskit_algorithms.optimizers import COBYLA
from qiskit_algorithms.utils.algorithm_globals import algorithm_globals

# %% [markdown]
# We are creating a QUBO instance of a Quadratic Program and solving it using Warm Start QAOA.
#
# Quantum Solver Class does the following:
# 1. takes as an input the affected flight's inventory id
# 2. maintains an list of relevant flights
# 3. Creates the appropriate Quadratic Program
# 4. Converts it into QUBO instance
# 5. Solve it using Warm Start QAOA (we use classical optimiser as either Cplex or COBYLA)
# 6. Return the list of alternate flights
#
# What the user needs to do:
# 1. Setup an object of the QuantumSolver
# 2. Call solve() method
#
# Flow of the functions:
# 1. __init__
# 2. __preProcess
#
# 1. solve()
# 2. quantumSolve()
# 3. __run()
# 4. QAOA_algo()
# 5. __postProcess()

# %%
class QuantumSolver:
    """
    Create Object of this class with required arguments .
    Call Solve method to solve the problem.
    """

    df = None  # INV.csv
    highval = 1000000  # used for incresing the weight of matrix
    inv_id: str  # stores the affected flight inventory id
    flight = None  # affected flight row
    FullList:dict  # Stores InventoryId of all the dirsrupted flights
    # =========
    # matrices to be used in Quadratic Program
    MatFlightTime: np.ndarray # Stores flight time of xi th flight. This will be also used to remove already got solutions.
    MatArrArp    : np.ndarray # 1 if ith flight is departure airport = impacted flight departure airport
    MatDepArp    : np.ndarray # 1 if ith flight is Arrival airport = impacted flight Arrival airport
    MatNeigh     : np.ndarray # 1 if ith flight have a flight whose arrivalAirport == departureAirport else 0
    MatGndDelay  : np.ndarray # stores the ground delay between ith and jth flight.
    MatTltDelay  : np.ndarray # stores total delay if this node is the last node(This remains zero for all flights whose arrival  airport is not = arrival airport of impacted flight)
    # ========

    def __init__(self, inv_id, ImpactedFlights:dict, inFile):
        """
            Input :
                inv_id:Corresponding inventory id of affected flight from the provided datafile
                ImpactedFlights: Dictionary of all the impacted flights
                inFile: Input File To take the flights from

            Creates a list of relevant flights, initializes matrices, and calls the QuantumSolve() function
        """

        self.df = inFile
        self.excp = False
        self.inv_id = inv_id
        self.FullList=ImpactedFlights

        self.lst = self.__preProcess()  # list of relevant flights
        if len(self.lst) == 0:  # no relevant flights present
            self.excp = True
        print(len(self.lst), "Feasible Flights\n")

        self.length = len(self.lst)
        self.length=min(self.length,10)

        # Initializing above mentioned flights
        self.MatFlightTime = np.zeros((self.length, self.length))
        self.MatNeigh, self.MatGndDelay= np.zeros_like(self.MatFlightTime), np.zeros_like(self.MatFlightTime)
        self.MatArrArp, self.MatDepArp, self.MatTltDelay=np.zeros((self.length,)),np.zeros((self.length,)),np.zeros((self.length,))

        print("\nAffected Flight\n")
        print(self.flight)


    def solve(self):
        """
        Returns the list of all the alternate solutions in order of best to worse.
        """
        if(self.excp):
          return []
        startTime = dt.datetime.now()
        ans = self.quantumSolve()  # invoke the quantum solve function
        TimeTaken=(dt.datetime.now() - startTime)
        print("TimeTaken:",TimeTaken)

        return ans


    def __diff(self, datetime1,datetime2):
        """
            returns difference in time of date2-date1
        """
        dt1 = dt.datetime.strptime(datetime1, "%Y-%m-%d %H:%M:%S")
        dt2 = dt.datetime.strptime(datetime2, "%Y-%m-%d %H:%M:%S")
        difference = dt2 - dt1
        return int(difference.total_seconds() // 60)


    def __preProcess(self) -> list:
        """
            Creates a list of relevant flights which have sensible departure and arrival times
        """

        # refer to above rule set to check which rule is being implemented
        index = self.df.loc[self.df["InventoryId"] == self.inv_id].index[0]  # get the index from the dataset
        self.flight = self.df.loc[index]  # affected flight
        list_of_feasible_flights = []
        impactedFlightStatus=self.FullList.get(self.flight["InventoryId"])
        currFlTime=self.__diff(datetime1=self.flight["DepartureDateTime"],datetime2=self.flight["ArrivalDateTime"])   # store flight time of impacted flight.
        arrivalsAt=dict()
        departsAt=dict()

        for i in range(len(self.df)):
            data = self.df.loc[i]
            if index == i:
                continue
            fromlst=self.FullList.get(data["InventoryId"])
            if fromlst:
                if fromlst=="Cancelled":  # If Flight is cancelled then do not add it. rule 8
                    continue
            if data["ArrivalAirport"] == self.flight["DepartureAirport"] or data["DepartureAirport"]==self.flight["ArrivalAirport"]:  # rule 5,6
                continue
            timebtwArr_Curdep = self.__diff(datetime1=self.flight["DepartureDateTime"], datetime2=data["ArrivalDateTime"])
            timebtwdep_CurrDep = self.__diff(datetime1=self.flight["DepartureDateTime"], datetime2=data["DepartureDateTime"])
            flightTime=self.__diff(datetime1=data["DepartureDateTime"], datetime2=data["ArrivalDateTime"])

            if impactedFlightStatus != "Cancelled" and self.__diff(datetime1=self.flight["ArrivalDateTime"], datetime2=data["ArrivalDateTime"]) > 0: # rule 9 If this flight is not cancelled then do not consider any flight taking more time than this.
                continue
            if timebtwArr_Curdep < 60 or timebtwdep_CurrDep > 72 * 60:   # rule 1,2,3  # following the Minimum Ground Time and Maximum Connecting Time
                continue
            elif flightTime > currFlTime and data["DepartureAirport"] != self.flight["DepartureAirport"] \
                    and data["ArrivalAirport"] != self.flight["ArrivalAirport"]:  # rule 4
                continue
            else:
                list_of_feasible_flights.append(data)
                if data["ArrivalAirport"] in arrivalsAt.keys():
                    arrivalsAt[data["ArrivalAirport"]]+=1
                else:
                    arrivalsAt[data["ArrivalAirport"]]=1
                if data["DepartureAirport"] in departsAt.keys():
                    departsAt[data["DepartureAirport"]]+=1
                else:
                    departsAt[data["DepartureAirport"]]=1

        for fl in list_of_feasible_flights:  # Removes all those flights for which no other flights preceeds them or no other flight succeed them
            if (fl["DepartureAirport"] not in departsAt.keys() or fl["ArrivalAirport"] not in arrivalsAt.keys()) and fl["DepartureAirport"] != self.flight["DepartureAirport"] and \
                fl["ArrivalAirport"]!= self.flight["ArrivalAirport"]:
                    list_of_feasible_flights.remove(fl)
        return list_of_feasible_flights

    def __run(self):
        """
            Creates the Matrices required for the Quadratic Program
        """
        ConsideredFlights = dict()  # to keep a tally of unique flights

        # Nodes
        for i in range(self.length):
            data = self.lst[i]  # a single flight

            if data["InventoryId"] not in ConsideredFlights:
                ConsideredFlights[data["InventoryId"]] = (
                    data["DepartureAirport"],
                    data["ArrivalAirport"],
                    data["DepartureDateTime"],
                    data["ArrivalDateTime"],
                )

                # Q Matrix measures the total time taken by the flight (Arr - Dep of the flight)
                self.MatFlightTime[i, i] = self.__diff(data["DepartureDateTime"], data["ArrivalDateTime"]) * 100

                # putting values to the matrices as defined above
                if data["DepartureAirport"] == self.flight["DepartureAirport"]:
                    self.MatArrArp[i] = 1
                    self.MatNeigh[i, i] = 1
                else:
                    self.MatArrArp[i] = 0
                if data["ArrivalAirport"] == self.flight["ArrivalAirport"]:
                    self.MatDepArp[i] = 1
                    self.MatTltDelay[i]=int(self.__diff(self.flight["DepartureDateTime"],data["ArrivalDateTime"]) * 100)
                else:
                    self.MatDepArp[i]= 0

                # Edges
                for j in range(self.length):
                    fl2 = self.lst[j]
                    if self.MatNeigh[i, i] == 1 and i != j:
                        self.MatGndDelay[i, j] = 0
                    else:
                        if data["DepartureAirport"] == fl2["ArrivalAirport"]:
                            self.MatNeigh[i, j] = 1
                            ti = int(self.__diff(fl2["ArrivalDateTime"], data["DepartureDateTime"]) * 100)  # minutes(fl2["DepartureTime"]) - minutes(data["ArrivalTime"])
                            if ti < 6000 or ti > 72000:
                                self.MatGndDelay[i, j] = self.highval
                                self.MatNeigh[i,j]=0
                            else:
                                self.MatGndDelay[i, j] = ti
                        else:
                            self.MatGndDelay[i, j] = 0


        self.MatGndDelay = self.MatGndDelay.astype(int)


    def QAOA_algo(self) -> list:
        """
        Main Function of the Class
        Quadratic Program : 1. Objective Function - MatFlightTime+MatGndDelay + MatTltDelay(linear)
                            2. Linear Constraints - MatArrArp & MatDepArp
                            3. Quadratic Constraints - MatNeigh
        Why QUBO - Each flight has two options - Either it can be in the path or not
        :return: list of alternate flights as
        """

        qp = QuadraticProgram("flights")
        F = self.MatFlightTime + self.MatGndDelay # quadratic form matrix
        F = F.astype(int)

        qp.minimize(linear=self.MatTltDelay,quadratic=F)  # matrices fed into the quadratic program
        qp.binary_var_list(self.length)
        qp.linear_constraint(np.ones(self.length, ), ">", 1)  # alteast 1 flights must be selected
        qp.linear_constraint(self.MatArrArp, "=", 1)          # There must be only and necessarily 1 flight with departureAirport = DepartureAirport of impacted flight
        qp.linear_constraint(self.MatDepArp, "=", 1)          # There must be only and necessarily 1 flight with ArrivalAirport = ArrivalAirport of impacted flight
        for i in range(self.length):                          # Applies the constraint that if a flight is on(1) then there must atleast 1 neighbouring flight that is on(1)
            linear=copy.deepcopy(self.MatNeigh[i,:])
            linear[i]-=1
            qp.linear_constraint(linear,">",0)

        #print("Variables : ",qp.get_num_binary_vars)

        # Classical Solver
        # start1 = dt.datetime.now()
        # ws_qaoa_result=(CplexOptimizer().solve(qp))
        # print(dt.datetime.now() - start1)
        # print(qp.prettyprint())

        # Quadratic  Solver
        algorithm_globals.random_seed = 12345
        qaoa_mes = QAOA(sampler=Sampler(), optimizer=COBYLA(maxiter=2))  # a qaoa instance of the quadratic program

        # ws_qaoa = WarmStartQAOAOptimizer(pre_solver=CobylaOptimizer(),relax_for_pre_solver=True,qaoa=qaoa_mes,epsilon=0.0)
        ws_qaoa = WarmStartQAOAOptimizer(pre_solver=CplexOptimizer(), relax_for_pre_solver=False, qaoa=qaoa_mes, epsilon=0.0)
        ws_qaoa_result = ws_qaoa.solve(qp)

        ans = list(ws_qaoa_result.variables_dict.values())

        return ans


    def quantumSolve(self) -> list:
        """
        Linker between all working functions
        :return: list of suitable alternative flights
        """

        total = []
        self.__run()  # we will get the Q A B N G matrices initialised now
        prevAns=[]

        # Runs the algorithm to get maximum number of solutions
        while True:
            ans=self.QAOA_algo()
            if ans == prevAns or ans in total:
                break
            prevAns=ans
            if prevAns == []:
                break
            total.append(self.__postProcess(ans[:self.length]))

        return total


    def __postProcess(self, bitString: list) -> list:
        """
        Convert the output from QAOA_algo() function into a suitable format
        :param bitString:
        :return: list of flights corresponding to the bitString
        """

        path = []
        isStarting=False;isEnding=False # TO check if path is complete (If not complete do no add this path)

        for i in range(len(bitString)):
            if bitString[i]==1:
                added=False
                # Loop to add the flights to the path in order that is like A->B,B->C ... not like B->C,A->B,...
                for idx in range(len(path)):
                    if path[idx]["ArrivalAirport"] == self.lst[i]["DepartureAirport"]:
                        path=path[:idx+1]+[self.lst[i]]+path[idx+1:] # Add this flight before idx th flight
                        added=True
                        break
                    if self.lst[i]["ArrivalAirport"] == path[idx]["DepartureAirport"]:
                        path=path[:idx]+[self.lst[i]]+path[idx:]  # Add this flight after idx th flight
                        added=True
                        break

                if self.lst[i]["DepartureAirport"]==self.flight["DepartureAirport"]:
                    isStarting=True
                    if not added:
                        path=[self.lst[i]]+path # Adds this flight to very start of the path.
                    added=True

                if self.lst[i]["ArrivalAirport"]==self.flight["ArrivalAirport"]:
                    isEnding=True
                if not added:
                    path.append(self.lst[i]) # Adds this flight to last of the path
        if not isEnding or not isStarting:
            return []

        # to increase the value of objective function for this path so that next time solver do not consider this flight again.
        for i in range(len(bitString)):
            if bitString[i]==0:
                continue
            for j in range(len(bitString)):
                if bitString[j] == 1 and i!=j:
                    self.MatFlightTime[i,j]=self.highval
                    self.MatFlightTime[j,i]=self.highval
        return path

# %% [markdown]
# A example
# ImpactedFlights={"INV-ZZ-1875559":"Cancelled","INV-ZZ-1529206":"Delayed","INV-ZZ-2640504":"Cancelled","INV-ZZ-5480266":"Delayed"}
#
# (QuantumSolver("INV-ZZ-1529206",ImpactedFlights,INVFile[0]).solve())  < -- returns the a list of all the alternate solution...
#
# Call this line for every entry of the dictionary:ImpactedFlights  ...

# %%
paths = {} # dictonary with keys as affected flight inv ids and values as alt flight paths
for flight in affected_flights.keys():
  paths[flight] = QuantumSolver(flight,affected_flights,data_frames['inventory']).solve()
# Out:
# 1 Feasible Flights
#
#
# Affected Flight
#
# InventoryId                                                 INV-ZZ-6984919
# ScheduleId                                                  SCH-ZZ-9117133
# CarrierCode                                                             ZZ
# Dep_Key                                             ZZ20240403BLRCCU2504.0
# FlightNumber                                                        2504.0
# AircraftType                                                    Boeing 777
# DepartureDate                                                   04/03/2024
# DepartureDateTime                                      2024-04-03 15:35:00
# ArrivalDateTime                                        2024-04-03 18:17:00
# DepartureAirport                                                       BLR
# ArrivalAirport                                                         CCU
# TotalCapacity                                                        425.0
# TotalInventory                                                         481
# BookedInventory                                                        295
# Oversold                                                              -130
# AvailableInventory                                                     186
# FirstClass                                                              42
# BusinessClass                                                           85
# PremiumEconomyClass                                                    127
# EconomyClass                                                           170
# FC_TotalInventory                                                       49
# FC_BookedInventory                                                      30
# FC_Oversold                                                             12
# FC_AvailableInventory                                                   19
# BC_TotalInventory                                                       96
# BC_BookedInventory                                                      59
# BC_Oversold                                                             26
# BC_AvailableInventory                                                   37
# PC_TotalInventory                                                      142
# PC_BookedInventory                                                      87
# PC_Oversold                                                             40
# PC_AvailableInventory                                                   55
# EC_TotalInventory                                                      192
# EC_BookedInventory                                                     118
# EC_Oversold                                                             52
# EC_AvailableInventory                                                   74
# FC_CD                                                   {'F': 25, 'P': 17}
# BC_CD                                          {'C': 34, 'J': 26, 'Z': 26}
# PC_CD                    {'Q': 38, 'R': 25, 'S': 13, 'T': 13, 'H': 25, ...
# EC_CD                    {'Y': 13, 'A': 13, 'B': 6, 'D': 6, 'E': 6, 'G'...
# Name: 120, dtype: object
# TimeTaken: 0:00:00.138322
# 0 Feasible Flights
#
#
# Affected Flight
#
# InventoryId                                                 INV-ZZ-5183618
# ScheduleId                                                  SCH-ZZ-6095474
# CarrierCode                                                             ZZ
# Dep_Key                                             ZZ20240407HYDAMD3723.0
# FlightNumber                                                        3723.0
# AircraftType                                               Airbus A320 Neo
# DepartureDate                                                   04/07/2024
# DepartureDateTime                                      2024-04-07 20:40:00
# ArrivalDateTime                                        2024-04-08 12:24:00
# DepartureAirport                                                       HYD
# ArrivalAirport                                                         AMD
# TotalCapacity                                                        180.0
# TotalInventory                                                         201
# BookedInventory                                                        123
# Oversold                                                               -57
# AvailableInventory                                                      78
# FirstClass                                                              18
# BusinessClass                                                           36
# PremiumEconomyClass                                                     54
# EconomyClass                                                            72
# FC_TotalInventory                                                       20
# FC_BookedInventory                                                      12
# FC_Oversold                                                              6
# FC_AvailableInventory                                                    8
# BC_TotalInventory                                                       43
# BC_BookedInventory                                                      26
# BC_Oversold                                                             10
# BC_AvailableInventory                                                   17
# PC_TotalInventory                                                       63
# PC_BookedInventory                                                      39
# PC_Oversold                                                             15
# PC_AvailableInventory                                                   24
# EC_TotalInventory                                                       82
# EC_BookedInventory                                                      50
# EC_Oversold                                                             22
# EC_AvailableInventory                                                   32
# FC_CD                                                    {'F': 11, 'P': 7}
# BC_CD                                          {'C': 14, 'J': 11, 'Z': 11}
# PC_CD                    {'Q': 16, 'R': 11, 'S': 5, 'T': 5, 'H': 11, 'M...
# EC_CD                    {'Y': 5, 'A': 5, 'B': 3, 'D': 3, 'E': 3, 'G': ...
# Name: 26, dtype: object

# %%
# __________________________________ ALLOCATION __________________________________

# Function to search for any special service
def search_for_special_service(pnr=None):
  conn = sqlite3.connect('data.db')
  cursor = conn.cursor()

  sql_query = ''' SELECT RECLOC, SPECIAL_NAME_CD1, SPECIAL_NAME_CD2, SSR_CODE_CD1 FROM pnrp WHERE (RECLOC = ?) '''

  cursor.execute(sql_query, (pnr,))

  result = cursor.fetchall()

  return result

# %%
## Function to score the passengers
def Score(passenger):
  score = 0
  special_service = search_for_special_service(passenger[0])
  for pnr in special_service:
    score += 50
    if pnr[1] == 'CHD' or pnr[1] == 'INF' or pnr[1] == 'UNN':
      score += 200
    if pnr[2] == 'NRPS':
      score += 200
    if pnr[3] == 'WCHR' or pnr[3] == 'BLND' or pnr[3] == 'DEAF':
      score += 200
  if passenger[4] == 'FirstClass':
    score += 2000
  elif passenger[4] == 'BusinessClass':
    score += 1800
  elif passenger[4] == 'PremiumClass':
    score += 1600
  elif passenger[4] == 'EconomyClass':
    score += 1500
  score += (100*(int(passenger[6]) - int(passenger[5])))
  return score

# %%
## Find the impacted passengers
passengers = {}
for flight in flights:
  passengers[flight] = list(get_affected_pnrb(flight.replace('-', '_')))
  for i in range(len(passengers[flight])):
    passengers[flight][i] = list(passengers[flight][i])
    passenger = passengers[flight][i]
    score = Score(passenger)
    passengers[flight][i].append(score)
  sorted_list = sorted(passengers[flight], key=lambda x: x[17], reverse=True)
  passengers[flight] = sorted_list

# %%
## Function to allocate passengers
def allocate(passenger, path):
  pnr = passenger[0]
  # print(path[4])
  pnr_class = passenger[4]
  pnr_cnt = int(passenger[7])
  flight_num = ''
  flight_departure = ''
  FC_available = int(path[22])
  BC_available = int(path[26])
  PC_available = int(path[30])
  EC_available = int(path[34])


  flight_num = int(path[4])
  flight_departure = str(path[6])
  Allocation=[]
  # Passenger has booked First Class
  if pnr_class == 'FirstClass':
    if FC_available - pnr_cnt >= 0:
      Allocation = ([flight_num, 'First Class', flight_departure])
      FC_available -= pnr_cnt
    elif BC_available - pnr_cnt >= 0:
      Allocation = ([flight_num, 'Business Class', flight_departure])
      BC_available -= pnr_cnt
    elif PC_available - pnr_cnt >= 0:
      Allocation = ([flight_num, 'Premium Class', flight_departure])
      PC_available -= pnr_cnt
    elif EC_available - pnr_cnt >= 0:
      Allocation = ([flight_num, 'Economy Class', flight_departure])
      EC_available -= pnr_cnt
    else:
      return []

  # Passenger has booke Business Class
  elif pnr_class == 'BusinessClass':
      if BC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'Business Class', flight_departure])
        BC_available -= pnr_cnt
      elif FC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'First Class', flight_departure])
        FC_available -= pnr_cnt
      elif PC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'Premium Class', flight_departure])
        PC_available -= pnr_cnt
      elif EC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'Economy Class', flight_departure])
        EC_available -= pnr_cnt
      else:
        return []

  # Passenger has booked Premium Class
  elif pnr_class == 'PremiumClass':
      if PC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'Premium Class', flight_departure])
        PC_available -= pnr_cnt
      elif BC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'Business Class', flight_departure])
        BC_available -= pnr_cnt
      elif EC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'Economy Class', flight_departure])
        EC_available -= pnr_cnt
      elif FC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'First Class', flight_departure])
        FC_available -= pnr_cnt
      else:
        return []

  # Passenger has booked Economy Class
  elif pnr_class == 'EconomyClass':
      if EC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'Economy Class', flight_departure])
        EC_available -= pnr_cnt
      elif PC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'Premium Class', flight_departure])
        PC_available -= pnr_cnt
      elif BC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'Business Class', flight_departure])
        BC_available -= pnr_cnt
      elif FC_available - pnr_cnt >= 0:
        Allocation = ([flight_num, 'First Class', flight_departure])
        FC_available -= pnr_cnt
      else:
        return []
  path[22] = FC_available
  path[26] = BC_available
  path[30] = PC_available
  path[34] = EC_available
  return Allocation

# %%
#--------------------------------- MAILING ALTERNATE SOLUTIONS TO PASSENGERS-------------------------------------------
import smtplib
import sys

def Mail(person,content):

  my_email = 'w0999288@gmail.com'  # sender dummy email
  password = "hirp uaww ixfa qjxr "  # app password
  with smtplib.SMTP('smtp.gmail.com', 587) as connection:
      connection.starttls()
      connection.login(user=my_email, password=password)
      connection.sendmail(
        from_addr=my_email, to_addrs=person[0],
        msg=f"Subject : Regarding your flight {person[1]} \n\n{content}"
      )
      connection.close()

# %%
def MailDefault(flight,solution,pnr):
  pnrp = data_frames['pnr_passenger']
  pnrb = data_frames['pnr_booking']
  inv = data_frames['inventory']
  invIdx=inv.loc[inv["InventoryId"]==flight].index[0]
  date=inv.loc[invIdx]["DepartureDateTime"]  # getting date of affected FLight
  flnum = inv.loc[invIdx]["FlightNumber"]
  pax = pnrp.loc[(pnrp["RECLOC"]==pnr)].index  # Get all the passengers associated with this pnr
  for pidx in pax:
    name = pnrp["FIRST_NAME"][pidx]+" "+pnrp["LAST_NAME"][pidx] # get passenger name
    mail = pnrp["CONTACT_EMAIL"][pidx]  # get passenger email
    s=""
    NOALFL=False
    for j,flrow in enumerate(solution):# iterating through each flight in this alternate path
        if flrow[1] == '-': # If there are no alternateFlights for this affectedFlight
          email = f"""Dear {name},\n\nWe regret to inform that your planned flight {int(flnum)} on {date} has been {affected_flights[flight]}.\nSorry for the inconvenience caused.\n\nBest wishes,\nAirlines\n"""
          print(email)
          NOALFL=True
          break
        invIdx2=inv.loc[inv["InventoryId"]==flrow[4]].index[0]
        date1=inv.loc[invIdx2]["DepartureDateTime"]  # getting date of this FLight
        s += f"\t{j+1}. {flrow[1]} departing on {date1}, assigned {flrow[2]}.\n"
    if not NOALFL:
      email = f"""Dear {name},\n\nWe regret to inform that your planned flight {int(flnum)} on {date} has been {affected_flights[flight]}.\nWe have provided some alternate flight options as given below:\n {s} \nBest wishes,\nAirlines\n"""
      print(email)
    # Mail([mail,flight],email)  # Mail to the person

# %%
import os

# Default solution Handling
def defaultSol(defaultsolLoc,Defaultvariables,AllotedDict) -> dict:
  MailsInfo=dict()
  for flight in AllotedDict:
    flInfo=[]
    AlternateSolutions=AllotedDict[flight]
    print(flight)
    csv_file_path = os.path.join('DefaultSol','DefaultReallocated_' + str(flight) + '.csv')
    # Writing data to the CSV file
    with open(csv_file_path, 'w', newline='') as csv_file:
      csv_writer = csv.writer(csv_file)
      csv_writer.writerow(['pnr','flightnum','Class','DepartureDate','InventoryId'])
      for pnr,rowstowrite in AlternateSolutions[defaultsolLoc[flight]].items():
        MailDefault(flight,rowstowrite,pnr)
        flInfo.append(rowstowrite)
        # print(rowstowrite)
        csv_writer.writerows(rowstowrite)

    variables=Defaultvariables[flight]
    for i,path in enumerate(paths[flight][defaultsolLoc[flight]]):
      path[22]=variables[i][0]
      path[26]=variables[i][1]
      path[30]=variables[i][2]
      path[34]=variables[i][3]

# %%
import csv

# Specify the file path
try:
  os.mkdir(os.path.join(os.getcwd(),'DefaultSol'))
except:
  pass

# MailsInfo=dict() # this contains info needed to mail for each pnr as its key.
AllotedDict=dict()
NotAllotedDict=dict()
defaultsolLoc=dict()
Defaultvariables=dict()

for flight in flights:
    # Alloted_classlstMail=[]  # This stores all the alloted_class info about each alternate path found by the solver for Mailing
    Alloted_classlstCsv=[] # This stores all the alloted_class info about each alternate path found by the solver for CSV file
    NotAllotedpnrs=[] # This stores all passenger not alloted to a particular solution

    if len(paths[flight]) == 0 and affected_flights[flight] == 'Delayed':
      csv_file_path = os.path.join(os.getcwd(),'DefaultSol','DefaultReallocated_' + str(flight) + '.csv')
      with open(csv_file_path, 'w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(['pnr','flightnum','Class','DepartureDate','InventoryId'])
        for passenger in passengers[flight]:
          pnr = passenger[0]
          pnr_class = passenger[4]
          csv_writer.writerow([pnr, '-', str(pnr_class), 'Delayed Time',flight])
          MailDefault(flight,[[pnr, '-', str(pnr_class), 'Delayed Time',flight]],pnr)
      continue

    max = -1;maxpos=-1;dfvaroffl=[]

    for i,solution in enumerate(paths[flight]):
      # allotedlstMail=[]  # This stores the flNum,Class,Date for each flight in a particular alternate path for Mailing
      alloteddictCsv=dict() # This stores the row of csv file
      notAllotedlstCsv=[] # This store the passengers which are not alloted to this solution
      backuplst=dict()  # To backup int(pathfl[22]),int(pathfl[26]),int(pathfl[30]),int(pathfl[34]) values for each flight in the path


      for passenger in passengers[flight]:
        lstClass=[]
        NA=False
        for pathfl in solution:
          if pathfl[0] not in backuplst.keys():
            backuplst[pathfl[0]]=(int(pathfl[22]),int(pathfl[26]),int(pathfl[30]),int(pathfl[34]))
          row=allocate(passenger,pathfl)
          if len(row) == 0:
            notAllotedlstCsv.append(passenger)
            NA=True
            break
          lstClass.append([passenger[0]]+row+[pathfl[0]])

        if not NA:
          alloteddictCsv[passenger[0]]=lstClass

      # Alloted_classlstMail.append(allotedlstMail)
      Alloted_classlstCsv.append(alloteddictCsv)
      NotAllotedpnrs.append(notAllotedlstCsv)

      defaultsolbackup=[]
      # Restoring the changed inventory values for each flights in the solution
      for pathfl in solution:
        defaultsolbackup.append((int(pathfl[22]),int(pathfl[26]),int(pathfl[30]),int(pathfl[34])))
        pathfl[22]=backuplst[pathfl[0]][0]
        pathfl[26]=backuplst[pathfl[0]][1]
        pathfl[30]=backuplst[pathfl[0]][2]
        pathfl[34]=backuplst[pathfl[0]][3]

      if len(alloteddictCsv) > max:
        max = len(solution)
        maxpos=i
        dfvaroffl=defaultsolbackup

    NotAllotedDict[flight]=NotAllotedpnrs
    AllotedDict[flight]=Alloted_classlstCsv
    defaultsolLoc[flight]=maxpos
    Defaultvariables[flight]=dfvaroffl
# Out:
# <ipython-input-503-7e71f219117e>:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path[22] = FC_available
# <ipython-input-503-7e71f219117e>:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path[26] = BC_available
# <ipython-input-503-7e71f219117e>:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path[30] = PC_available
# <ipython-input-503-7e71f219117e>:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path[34] = EC_available
# <ipython-input-507-0222d38831a8>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathfl[22]=backuplst[pathfl[0]][0]
# <ipython-input-507-0222d38831a8>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathfl[26]=backuplst[pathfl[0]][1]
# <ipython-input-507-0222d38831a8>:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathfl[30]=backuplst[pathfl[0]][2]
# <ipython-input-507-0222d38831a8>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathfl[34]=backuplst[pathfl[0]][3]
# Dear Zaina Sibal,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Hrishita Kari,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Khushi Dyal,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Divij Bandi,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Yuvaan Bir,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Bhavin Apte,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Stuvan Rege,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Katherine Dennis,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Charles Gibson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Christine Jones,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Trisha Mand,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Michael Browning,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Heather Jones,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Stephanie Johnson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Elizabeth Dodson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Riya Dar,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Nehmat Lal,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Alia Koshy,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Manikya Majumdar,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Eric Ortiz,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Bryan Garcia,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Misha Ghosh,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Ehsaan Hora,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Nitara Joshi,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Bhavin Zacharia,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Debra Solis,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Matthew Herring,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear David Snyder,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Kimberly Durham,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Uthkarsh Rao,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Darren Graham,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Gerald Williams,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Yuvraj  Venkatesh,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Gokul Kibe,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Derek Moore,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Stephanie Young,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Ryan De,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Brittany Pope,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Miranda Dillon,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Michael Navarro,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Diana Ibarra,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jhanvi Krish,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Sean Reed,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear James Hinton,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jenna Hall,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Erin Carter,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Neysa Grewal,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Badal Gaba,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Seth Kane,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Kashvi Saini,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Michael Brown,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Joseph Jones,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Sean Mathews,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Mohanlal Deshmukh,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Andrea Keller,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Brian Allison,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Donna Wright,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Shamik Ben,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Indranil Hari,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Sara Bhatti,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Allison Kane,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Brian Wilson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Timothy Smith,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Riya Kamdar,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Samiha Tank,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Saanvi Kalla,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Johnathan Brooks,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Kara Peterson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Eva Sane,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear

#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Ivana Buch,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Arnav Tella,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Justin Clark,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Sue Ho,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Vickie Marks,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Samarth Bassi,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jennifer West,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Ethan Garza,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Carolyn Brock,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Paul Harris,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Mishti Bhatt,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Ashley Chase,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Lisa Bishop,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Khushi Bhatti,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Stephanie Singh,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Eric Williams,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jasmine Golden,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Lisa Walker,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Karen Jackson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Amy Meyer,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Ariel Fitzgerald,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Taylor Davis,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Faiyaz Kara,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Zara Lad,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Michael Garner,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jose Sullivan,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Robert Mckinney,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Whitney Zamora,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Faiyaz Goda,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Nayantara Mammen,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Derek Davis,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Lavanya Viswanathan,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Anay Varty,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Kevin Keller,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Karen Welch,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Catherine Clark,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jennifer Johnson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Kevin Smith,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Anya Srinivas,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Adira Kapoor,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Purab Singhal,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Laura Leblanc,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Arhaan Som,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Timothy Henson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Michelle Kennedy,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Christina Anderson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Max Cortez,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Antonio Johnson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Angela Gillespie,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Myra Bakshi,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jiya Boase,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Inaaya  Sehgal,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Shray Malhotra,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Rodney Ray,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Priyansh Bhatt,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Ayesha Konda,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Keya Kapadia,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear David Ellis,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jennifer Bryant,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Richard Evans,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Navya Chakraborty,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear James Mcdonald,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Vivaan Sane,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jose Jarvis,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jared Scott,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear George Baker,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Faiyaz Dutta,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Kiara Raman,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Armaan Iyengar,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear David Watson,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Cindy Cooper,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Crystal Medina,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Purab Dar,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jeffrey Krause,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Ellen Smith,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jody Scott,
#
# We regret to inform that your planned flight 3723 on 2024-04-07 20:40:00 has been Delayed.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines

# %%
MailsInfo=defaultSol(defaultsolLoc,Defaultvariables,AllotedDict)
# Out:
# INV-ZZ-6984919
# Dear Chirag Bajwa,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned First Class.
#
# Best wishes,
# Airlines
#
# Dear Michelle Crawford,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned First Class.
#
# Best wishes,
# Airlines
#
# Dear Brian Stone,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned First Class.
#
# Best wishes,
# Airlines
#
# Dear Ryan Singhal,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned First Class.
#
# Best wishes,
# Airlines
#
# Dear Heather Jones,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Stephanie Johnson,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Elizabeth Dodson,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Riya Dar,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Nehmat Lal,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Alia Koshy,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Renee Durham,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Donald Torres,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Molly Robinson,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear John Tapia,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Nehmat Ramakrishnan,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Lori Burnett,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Aarav Taneja,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear William Williamson,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Tarini Loke,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned First Class.
#
# Best wishes,
# Airlines
#
# Dear Dhanush Batra,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assig

#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Darshit Gole,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Neysa Ben,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Brenda Choi,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Chris Gonzalez,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Lisa Nelson,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Paul Park,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Ryan Smith,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Cindy Johnson,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Brent Harris,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Joshua Woodward,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Kimberly Williams,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Keya Sengupta,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Premium Class.
#
# Best wishes,
# Airlines
#
# Dear Rania Chacko,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Allison Barrera,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Michele Mcdonald,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Zain Sridhar,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
#
# Dear Kelsey Martinez,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# We have provided some alternate flight options as given below:
#  	1. 2504 departing on 2024-04-04 15:35:00, assigned Economy Class.
#
# Best wishes,
# Airlines
# <ipython-input-506-1b91d5176797>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path[22]=variables[i][0]
# <ipython-input-506-1b91d5176797>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path[26]=variables[i][1]
# <ipython-input-506-1b91d5176797>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path[30]=variables[i][2]
# <ipython-input-506-1b91d5176797>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   path[34]=variables[i][3]

# %%
# Exception List Handling
csv_file_path = 'Exception_list.csv'
with open(csv_file_path, 'w', newline='') as csv_file:
  csv_writer = csv.writer(csv_file)
  csv_writer.writerow(['pnr','flightnum','Class','DepartureDate'])

  for flight in NotAllotedDict.keys():
    for passenger in NotAllotedDict[flight][defaultsolLoc[flight]]:
      pnr = passenger[0]
      pnr_class = passenger[4]
      pnr_cnt = int(passenger[7])
      allocations = []
      for i,solution in enumerate(paths[flight]):
        if i == defaultsolLoc[flight]:
          continue
        allocations = allocate(passenger, solution)
        if allocations != []:
          for allocation in allocations:
            csv_writer.writerow([pnr, allocation[0], allocation[1], allocation[2]])
            MailDefault(flight,[[pnr, allocation[0], allocation[1], allocation[2],solution[0]]],pnr)
          break
      if allocations == []:
        MailDefault(flight,[[pnr, '-', 'Not Alloted', affected_flights[flight]]],pnr)
        csv_writer.writerow([pnr, affected_flights[flight], 'Not Alloted', affected_flights[flight]])
# Out:
# Dear Kelly Carter,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Faiyaz Khatri,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Kristina Mendez,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Brian Scott,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear James Mcconnell,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Nishith Bedi,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Gwendolyn Rowe,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Marvin Edwards,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Thomas Moore,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Ahana  Kamdar,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Zain Sidhu,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Kelly Williams,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Matthew Hines,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Jennifer Gallagher,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Carlos Martin,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Anay Balan,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Maria Dunn,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Baiju Ramanathan,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Andrew Jackson,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Madhav Wadhwa,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear Alexis Bowen,
#
# We regret to inform that your planned flight 2504 on 2024-04-03 15:35:00 has been Cancelled.
# Sorry for the inconvenience caused.
#
# Best wishes,
# Airlines
#
# Dear